# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse
import time

# %%
url = "https://www.paulaschoice.com/ingredient-dictionary/ingredient-10-hydroxydecanoic-acid.html?fdid=ingredients"
parsed = urlparse(url)

path = parsed.path
path
# Out:
# '/ingredient-dictionary/ingredient-10-hydroxydecanoic-acid.html'
